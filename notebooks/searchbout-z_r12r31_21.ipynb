# %% [markdown]
# ## Searching for bouts for a day of alsa recording

# %%
# %matplotlib inline
import os
import glob
import socket
import logging
import numpy as np
import pandas as pd
from scipy.io import wavfile
from scipy import signal

from matplotlib import pyplot as plt

from importlib import reload

logger = logging.getLogger()
handler = logging.StreamHandler()
formatter = logging.Formatter(
        '%(asctime)s %(name)-12s %(levelname)-8s %(message)s')
handler.setFormatter(formatter)
logger.addHandler(handler)
logger.setLevel(logging.INFO)

logger.info('Running on {}'.format(socket.gethostname()))
# Out:
# 2021-07-23 10:54:31,346 root         INFO     Running on pakhi

# %%
from ceciestunepipe.file import bcistructure as et

# %% [markdown]
# ### Get the file locations for a session (day) of recordings

# %%
reload(et)
sess_par = {'bird': 'z_r12r13_21',
           'sess': '2021-06-10'}


exp_struct = et.get_exp_struct(sess_par['bird'], sess_par['sess'], ephys_software='alsa')

raw_folder = exp_struct['folders']['alsa']

# %%
exp_struct['folders']
# Out:
# {'bird': '/mnt/sphere/speech_bci/raw_data/z_r12r13_21',
#  'raw': '/mnt/sphere/speech_bci/raw_data/z_r12r13_21/2021-06-10',
#  'alsa': '/mnt/sphere/speech_bci/raw_data/z_r12r13_21/2021-06-10/alsa',
#  'kwik': '/scratch/earneodo/z_r12r13_21/alsa/kwik/2021-06-10',
#  'processed': '/mnt/sphere/speech_bci/processed_data/z_r12r13_21/2021-06-10/alsa',
#  'derived': '/mnt/sphere/speech_bci/derived_data/z_r12r13_21/2021-06-10/alsa',
#  'tmp': '/scratch/earneodo/tmp',
#  'msort': '/scratch/earneodo/z_r12r13_21/alsa/msort/2021-06-10',
#  'ksort': '/scratch/earneodo/z_r12r13_21/alsa/ksort/2021-06-10'}

# %% [markdown]
# #### search parameters
# Spectrograms are computed using librosa
#
# Additional parameters are for bout search criteria and functions to read the data

# %%
# function for getting one channel out of a wave file
def read_wav_chan(wav_path: str, chan_id: int=0) -> tuple:
    s_f, x = wavfile.read(wav_path, mmap=True)
    return s_f, x[:, chan_id]

def sess_file_id(f_path):
    n = int(os.path.split(f_path)[1].split('-')[-1].split('.wav')[0])
    return n

hparams = {
    # spectrogram
    'num_freq':1024, #1024# how many channels to use in a spectrogram #
    'preemphasis':0.97, 
    'frame_shift_ms':5, # step size for fft
    'frame_length_ms':10, #128 # frame length for fft FRAME SAMPLES < NUM_FREQ!!!
    'min_level_db':-55, # minimum threshold db for computing spe 
    'ref_level_db':110, # reference db for computing spec
    'sample_rate':None, # sample rate of your data
    
    # spectrograms
    'mel_filter': False, # should a mel filter be used?
    'num_mels':1024, # how many channels to use in the mel-spectrogram
    'fmin': 300, # low frequency cutoff for mel filter
    'fmax': 7000, # high frequency cutoff for mel filter
    
    # spectrogram inversion
    'max_iters':200,
    'griffin_lim_iters':20,
    'power':1.5,

    # Added for the searching
    'read_wav_fun': read_wav_chan, # function for loading the wav_like_stream (has to returns fs, ndarray)
    'file_order_fun': sess_file_id, # function for extracting the file id within the session
    'min_segment': 15, # Minimum length of supra_threshold to consider a 'syllable' (ms)
    'min_silence': 2000, # Minmum distance between groups of syllables to consider separate bouts (ms)
    'min_bout': 200, # min bout duration (ms)
    'peak_thresh_rms': 0.55, # threshold (rms) for peak acceptance,
    'thresh_rms': 0.25, # threshold for detection of syllables
    'mean_syl_rms_thresh': 0.3, #threshold for acceptance of mean rms across the syllable (relative to rms of the file)
    'max_bout': 20000, #exclude bouts too long (ms)
    'l_p_r_thresh': 100, # threshold for n of len_ms/peaks (typycally about 2-3 syllable spans
    
    'waveform_edges': 1000, #get number of ms before and after the edges of the bout for the waveform sample
    
    'bout_auto_file': 'bout_auto.pickle', # extension for saving the auto found files
    'bout_curated_file': 'bout_checked.pickle', #extension for manually curated files (coming soon)
    }

# %% [markdown]
# #### Get one wave file

# %%
one_wav_path = os.path.join(exp_struct['folders']['alsa'], '07-00-01-02.wav')

s_f, x = read_wav_chan(one_wav_path)

hparams['sample_rate'] = s_f

# %%
x.shape
# Out:
# (81600000,)

# %%
plt.plot(x[:50000])

# %% [markdown]
# ### try the function to search for bouts in the file

# %%
from ceciestunepipe.util.sound import boutsearch as bs

# %%
bpd, x, p = bs.get_bouts_in_file(one_wav_path, hparams)
# Out:
# 2021-07-23 12:09:27,670 ceciestunepipe.util.sound.boutsearch INFO     Getting bouts for file /mnt/sphere/speech_bci/raw_data/z_r12r13_21/2021-06-10/alsa/07-00-01-02.wav
# tu vieja file /mnt/sphere/speech_bci/raw_data/z_r12r13_21/2021-06-10/alsa/07-00-01-02.wav

# %%
bpd
# Out:
#     start_ms   end_ms  start_sample  end_sample  \
# 0      16915    34690        811920     1665120
# 1      39295    53225       1886160     2554800
# 2      57535    62205       2761680     2985840
# 3      83170    86290       3992160     4141920
# 4      88610    91395       4253280     4386960
# 5      96015   114310       4608720     5486880
# 6     132300   139805       6350400     6710640
# 7     141840   143720       6808320     6898560
# 8     147055   159410       7058640     7651680
# 9     291040   304120      13969920    14597760
# 10    312000   315115      14976000    15125520
# 11    325395   330455      15618960    15861840
# 12    418015   432615      20064720    20765520
# 13    435015   436345      20880720    20944560
# 14    438580   445315      21051840    21375120
# 15    451965   458835      21694320    22024080
# 16    461010   465955      22128480    22365840
# 17    469140   470640      22518720    22590720
# 18    540095   552440      25924560    26517120
# 19    904270   904480      43404960    43415040
# 20   1000330  1012900      48015840    48619200
# 21   1015580  1018070      48747840    48867360
# 22   1026620  1032325      49277760    49551600
# 23   1035885  1045625      49722480    50190000
# 24   1047690  1051600      50289120    50476800
# 25   1058225  1067115      50794800    51221520
# 26   1069550  1073015      51338400    51504720
# 27   1078415  1083195      51763920    51993360
# 28   1093635  1100440      52494480    52821120
# 29   1208400  1208845      58003200    58024560
# 30   1261405  1266945      60547440    60813360
# 31   1269170  1275560      60920160    61226880
# 32   1277790  1280710      61333920    61474080
# 33   1339190  1356055      64281120    65090640
# 34   1358270  1363225      65196960    65434800
# 35   1367070  1371050      65619360    65810400
# 36   1379340  1385365      66208320    66497520
# 37   1390360  1401815      66737280    67287120
# 38   1405605  1410940      67469040    67725120
# 39   1427320  1444310      68511360    69326880
# 40   1455210  1465465      69850080    70342320
# 41   1478340  1479280      70960320    71005440
# 42   1488110  1488770      71429280    71460960
#
#                                                p_step     rms_p     peak_p  \
# 0   [0.925744381678091, 0.9378200261414915, 0.9093...  1.603198  32.783349
True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   17775
# 1         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   13930
# 2         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    4670
# 3         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    3120
# 4         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    2785
# 5         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   18295
# 6         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    7505
# 7         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    1880
# 8         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   12355
# 9         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   13080
# 10        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    3115
# 11        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    5060
# 12        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   14600
# 13        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    1330
# 14        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    6735
# 15        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    6870
# 16        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    4945
# 17        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    1500
# 18        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   12345
# 19        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...     210
# 20        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   12570
# 21        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    2490
# 22        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    5705
# 23        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    9740
# 24        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    3910
# 25        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    8890
# 26        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    3465
# 27        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    4780
# 28        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    6805
# 29        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...     445
# 30        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    5540
# 31        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    6390
# 32        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    2920
# 33        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   16865
# 34        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    4955
# 35        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    3980
# 36        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    6025
# 37        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   11455
# 38        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    5335
# 39        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   16990
# 40        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   10255
# 41        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...     940
# 42        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...     660
#
#                                                syl_in  n_syl  \
# 0   [[16915, 16940], [17065, 17085], [17240, 17255...     78
# 1   [[39295, 39310], [39375, 39405], [39530, 39550...     58
# 2   [[57535, 57555], [58815, 58855], [58980, 58995...     18
# 3   [[83170, 83190], [84175, 84195], [84260, 84285...     17
# 4   [[88610, 88625], [88690, 88730], [88850, 88870...     17
# 5   [[96015, 96055], [96180, 96195], [96430, 96455...     72
# 6   [[132300, 132325], [132450, 132470], [132705, ...     35
# 7   [[141840, 141860], [142090, 142130], [142180, ...     12
# 8   [[147055, 147080], [147315, 147350], [147405, ...     48
# 9   [[291040, 291055], [291290, 291325], [291385, ...     48
# 10  [[312000, 312020], [312250, 312290], [312345, ...     17
# 11  [[325395, 325410], [325640, 325685], [325740, ...     22
# 12  [[418015, 418115], [419140, 419160], [419390, ...     71
# 13  [[435015, 435040], [435175, 435190], [435430, ...     10
# 14  [[438580, 438605], [438725, 438750], [438985, ...     31
# 15  [[451965, 451985], [452630, 452655], [454240, ...     24
# 16  [[461010, 461040], [461275, 461310], [461365, ...     20
# 17               [[469140, 469160], [470625, 470640]]      2
# 18  [[540095, 540115], [540340, 540375], [540435, ...     46
# 19  [[904270, 904285], [904315, 904330], [904360, ...      5
# 20  [[1000330, 1000345], [1000570, 1000590], [1000...     52
# 21  [[1015580, 1015600], [1015735, 1015760], [1015...     14
# 22  [[1026620, 1026635], [1026870, 1026910], [1026...     25
# 23  [[1035885, 1035915], [1036040, 1036060], [1036...     36
# 24  [[1047690, 1047715], [1048100, 1048130], [1048...      6
# 25  [[1058225, 1058240], [1058435, 1058465], [1058...     40
# 26  [[1069550, 1069585], [1069715, 1069735], [1069...     14
# 27  [[1078415, 1078450], [1078575, 1078595], [1078...     27
# 28  [[1093635, 1093655], [1093715, 1093740], [1093...     35
# 29  [[1208400, 1208420], [1208650, 1208680], [1208...      4
# 30  [[1261405, 1261425], [1261655, 1261690], [1261...     31
# 31  [[1269170, 1269210], [1269260, 1269295], [1269...     23
# 21  [5, 1, -1, -6, -8, -12, -16, -20, -22, -22, -2...
# 22  [58, 53, 54, 50, 45, 44, 38, 36, 35, 32, 33, 3...
# 23  [-88, -87, -86, -85, -84, -83, -81, -79, -78, ...
# 24  [-48, -51, -53, -54, -56, -58, -58, -59, -57, ...
# 25  [65, 67, 69, 69, 69, 70, 70, 69, 69, 67, 66, 6...
# 26  [14, 14, 12, 9, 10, 8, 8, 8, 9, 12, 13, 16, 17...
# 27  [-64, -66, -65, -67, -68, -67, -68, -69, -70, ...
# 28  [-39, -40, -39, -41, -42, -43, -44, -46, -47, ...
# 29  [62, 59, 58, 55, 50, 47, 45, 43, 41, 38, 36, 3...
# 30  [12, 13, 13, 15, 17, 18, 19, 20, 22, 22, 23, 2...
# 31  [82, 83, 81, 80, 80, 79, 78, 76, 72, 68, 63, 6...
# 32  [-54, -56, -55, -56, -56, -54, -54, -53, -52, ...
# 33  [22, 21, 18, 16, 17, 16, 16, 17, 16, 14, 11, 1...
# 34  [43, 44, 44, 45, 44, 44, 44, 42, 41, 40, 38, 3...
# 35  [-26, -24, -23, -22, -21, -20, -19, -21, -21, ...
# 36  [24, 23, 22, 20, 19, 19, 18, 18, 18, 19, 19, 1...
# 37  [67, 68, 69, 70, 70, 69, 68, 68, 66, 65, 65, 6...
# 38  [51, 48, 44, 41, 39, 32, 26, 21, 17, 13, 6, 0,...
# 39  [-43, -38, -39, -43, -4, -49, -36, -4, -37, -2...
# 40  [-55, -56, -55, -56, -57, -56, -55, -55, -55, ...
# 41  [13, 14, 14, 12, 10, 8, 6, 2, 0, -3, -6, -8, -...
# 42  [-34, -35, -34, -34, -35, -34, -34, -32, -31, ...

# %%
plt.plot(bpd['waveform'].values[0])

# %%
bpd
# Out:
#     start_ms   end_ms  start_sample  end_sample  \
# 0      16915    34690        811920     1665120
# 1      39295    53225       1886160     2554800
# 2      57535    62205       2761680     2985840
# 3      83170    86290       3992160     4141920
# 4      88610    91395       4253280     4386960
# 5      96015   114310       4608720     5486880
# 6     132300   139805       6350400     6710640
# 7     141840   143720       6808320     6898560
# 8     147055   159410       7058640     7651680
# 9     291040   304120      13969920    14597760
# 10    312000   315115      14976000    15125520
# 11    325395   330455      15618960    15861840
# 12    418015   432615      20064720    20765520
# 13    435015   436345      20880720    20944560
# 14    438580   445315      21051840    21375120
# 15    451965   458835      21694320    22024080
# 16    461010   465955      22128480    22365840
# 17    469140   470640      22518720    22590720
# 18    540095   552440      25924560    26517120
# 19    904270   904480      43404960    43415040
# 20   1000330  1012900      48015840    48619200
# 21   1015580  1018070      48747840    48867360
# 22   1026620  1032325      49277760    49551600
# 23   1035885  1045625      49722480    50190000
# 24   1047690  1051600      50289120    50476800
# 25   1058225  1067115      50794800    51221520
# 26   1069550  1073015      51338400    51504720
# 27   1078415  1083195      51763920    51993360
# 28   1093635  1100440      52494480    52821120
# 29   1208400  1208845      58003200    58024560
# 30   1261405  1266945      60547440    60813360
# 32  [6.663823639374794, 9.393848979589228, 10.3202...  1.603198  22.155962
# 33  [0.7920412041284676, 1.5713473337332267, 1.705...  1.603198  18.623127
# 34  [0.4956969205077521, 1.0067002281700446, 2.110...  1.603198  16.297487
# 35  [0.5997296639704898, 0.7487430920262954, 1.158...  1.603198  14.512133
# 36  [2.9098044004479253, 4.12193140630778, 2.18708...  1.603198  29.770408
# 37  [0.8815222520440545, 0.9966735843875104, 0.857...  1.603198  29.856905
# 38  [2.207783524137094, 3.3175470354767196, 0.8333...  1.603198  13.677131
# 39  [3.650457739407137, 11.550251750397134, 12.942...  1.603198  39.095598
# 40  [1.138148014005684, 1.4606259196654645, 1.5654...  1.603198  35.147434
# 41  [0.7489295140912172, 1.0635927870964694, 1.697...  1.603198   1.774338
# 42  [0.9541849082716178, 0.44930426864431483, 0.50...  1.603198   2.523951
#
#     bout_check                                               file  len_ms  \
# 0         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   17775
# 1         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   13930
# 2         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    4670
# 3         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    3120
# 4         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    2785
# 5         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   18295
# 6         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    7505
# 7         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    1880
# 8         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   12355
# 9         True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   13080
# 10        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    3115
# 11        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    5060
# 12        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   14600
# 13        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    1330
# 14        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    6735
# 15        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    6870
# 16        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    4945
# 17        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    1500
# 18        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   12345
# 19        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...     210
# 20        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   12570
# 21        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    2490
# 22        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    5705
# 23        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    9740
# 24        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    3910
# 25        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    8890
# 26        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    3465
# 27        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    4780
# 28        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    6805
# 29        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...     445
# 30        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    5540
# 31        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    6390
# 32        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    2920
# 33        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   16865
# 34        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    4955
# 35        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    3980
# 36        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    6025
# 37        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   11455
# 38        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...    5335
# 39        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   16990
# 40        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...   10255
# 41        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...     940
# 42        True  /mnt/sphere/speech_bci/raw_data/z_r12r13_21/20...     660
#
#                                                syl_in  n_syl  \
# 0   [[16915, 16940], [17065, 17085], [17240, 17255...     78
# 1   [[39295, 39310], [39375, 39405], [39530, 39550...     58
# 2   [[57535, 57555], [58815, 58855], [58980, 58995...     18
# 3   [[83170, 83190], [84175, 84195], [84260, 84285...     17
# 4   [[88610, 88625], [88690, 88730], [88850, 88870...     17
# 5   [[96015, 96055], [96180, 96195], [96430, 96455...     72
# 6   [[132300, 132325], [132450, 132470], [132705, ...     35
# 7   [[141840, 141860], [142090, 142130], [142180, ...     12
# 8   [[147055, 147080], [147315, 147350], [147405, ...     48
# 9   [[291040, 291055], [291290, 291325], [291385, ...     48
# 10  [[312000, 312020], [312250, 312290], [312345, ...     17
# 11  [[325395, 325410], [325640, 325685], [325740, ...     22
# 12  [[418015, 418115], [419140, 419160], [419390, ...     71
# 13  [[435015, 435040], [435175, 435190], [435430, ...     10
# 14  [[438580, 438605], [438725, 438750], [438985, ...     31
# 15  [[451965, 451985], [452630, 452655], [454240, ...     24
# 16  [[461010, 461040], [461275, 461310], [461365, ...     20
# 17               [[469140, 469160], [470625, 470640]]      2
# 18  [[540095, 540115], [540340, 540375], [540435, ...     46
# 19  [[904270, 904285], [904315, 904330], [904360, ...      5
# 20  [[1000330, 1000345], [1000570, 1000590], [1000...     52
# 12  [-48, -49, -45, -47, -45, -43, -47, -50, -49, ...
# 13  [43, 43, 43, 40, 41, 44, 43, 42, 48, 47, 45, 5...
# 14  [22, 19, 18, 12, 14, 14, 10, 8, 7, 5, 5, 7, 7,...
# 15  [2, 2, 1, 2, 0, -2, -6, -10, -13, -15, -15, -2...
# 16  [75, 80, 84, 87, 90, 90, 91, 92, 90, 89, 87, 8...
# 17  [25, 28, 31, 35, 41, 42, 43, 43, 45, 53, 46, 3...
# 18  [1, 3, 5, 9, 12, 12, 11, 12, 13, 12, 13, 12, 8...
# 19  [43, 42, 42, 43, 42, 39, 37, 36, 36, 34, 33, 3...
# 20  [-34, -28, -31, -30, -25, -22, -17, -12, -10, ...
# 21  [5, 1, -1, -6, -8, -12, -16, -20, -22, -22, -2...
# 22  [58, 53, 54, 50, 45, 44, 38, 36, 35, 32, 33, 3...
# 23  [-88, -87, -86, -85, -84, -83, -81, -79, -78, ...
# 24  [-48, -51, -53, -54, -56, -58, -58, -59, -57, ...
# 25  [65, 67, 69, 69, 69, 70, 70, 69, 69, 67, 66, 6...
# 26  [14, 14, 12, 9, 10, 8, 8, 8, 9, 12, 13, 16, 17...
# 27  [-64, -66, -65, -67, -68, -67, -68, -69, -70, ...
# 28  [-39, -40, -39, -41, -42, -43, -44, -46, -47, ...
# 29  [62, 59, 58, 55, 50, 47, 45, 43, 41, 38, 36, 3...
# 30  [12, 13, 13, 15, 17, 18, 19, 20, 22, 22, 23, 2...
# 31  [82, 83, 81, 80, 80, 79, 78, 76, 72, 68, 63, 6...
# 32  [-54, -56, -55, -56, -56, -54, -54, -53, -52, ...
# 33  [22, 21, 18, 16, 17, 16, 16, 17, 16, 14, 11, 1...
# 34  [43, 44, 44, 45, 44, 44, 44, 42, 41, 40, 38, 3...
# 35  [-26, -24, -23, -22, -21, -20, -19, -21, -21, ...
# 36  [24, 23, 22, 20, 19, 19, 18, 18, 18, 19, 19, 1...
# 37  [67, 68, 69, 70, 70, 69, 68, 68, 66, 65, 65, 6...
# 38  [51, 48, 44, 41, 39, 32, 26, 21, 17, 13, 6, 0,...
# 39  [-43, -38, -39, -43, -4, -49, -36, -4, -37, -2...
# 40  [-55, -56, -55, -56, -57, -56, -55, -55, -55, ...
# 41  [13, 14, 14, 12, 10, 8, 6, 2, 0, -3, -6, -8, -...
# 42  [-34, -35, -34, -34, -35, -34, -34, -32, -31, ...

# %%
hparams
# Out:
# {'num_freq': 1024,
#  'preemphasis': 0.97,
#  'frame_shift_ms': 5,
#  'frame_length_ms': 10,
#  'min_level_db': -55,
#  'ref_level_db': 110,
#  'sample_rate': 48000,
#  'mel_filter': False,
#  'num_mels': 1024,
#  'fmin': 300,
#  'fmax': 7000,
#  'max_iters': 200,
#  'griffin_lim_iters': 20,
#  'power': 1.5,
#  'read_wav_fun': <function __main__.read_wav_chan(wav_path: str, chan_id: int = 0) -> tuple>,
#  'file_order_fun': <function __main__.sess_file_id(f_path)>,
#  'min_segment': 15,
#  'min_silence': 2000,
#  'min_bout': 200,
#  'peak_thresh_rms': 0.55,
#  'thresh_rms': 0.25,
#  'mean_syl_rms_thresh': 0.3,
#  'max_bout': 20000,
#  'l_p_r_thresh': 100,
#  'waveform_edges': 1000,
#  'bout_auto_file': 'bout_auto.pickle',
#  'bout_curated_file': 'bout_checked.pickle'}

# %% [markdown]
# ### get all bouts of the day

# %%
from joblib import Parallel, delayed

# %%
reload(bs)
# Out:
# <module 'ceciestunepipe.util.sound.boutsearch' from '/mnt/cube/earneodo/repos/ceciestunepipe/ceciestunepipe/util/sound/boutsearch.py'>

# %%
def get_all_day_bouts(sess_par: dict, hparams:dict, n_jobs: int=12) -> pd.DataFrame:
    
    logger.info('Will search for bouts through all session {}, {}'.format(sess_par['bird'], sess_par['sess']))
    exp_struct = et.get_exp_struct(sess_par['bird'], sess_par['sess'], ephys_software='alsa')

    # get all the paths to the wav files of the day
    raw_folder = exp_struct['folders']['alsa']
    wav_path_list = glob.glob(os.path.join(exp_struct['folders']['alsa'], '*.wav'))
    wav_path_list.sort()
    logger.info('Found {} files'.format(len(wav_path_list)))
    
    def get_file_bouts(i_path):
        return bs.get_bouts_in_file(i_path, hparams)[0]
    
    # Go parallel through all the paths in the day, get a list of all the pandas dataframes for each file
    sess_pd_list = Parallel(n_jobs=n_jobs, verbose=100, backend=None)(delayed(get_file_bouts)(i) for i in wav_path_list)
    
    #sess_pd_list = [bs.get_bouts_in_file(i, hparams)[0] for i in wav_path_list]
    
    # concatenate the file and return it, eventually write to a pickle
    sess_bout_pd = pd.concat(sess_pd_list)
    return sess_bout_pd

sess_bout_pd = get_all_day_bouts(sess_par, hparams, n_jobs=28)
# Out:
# 2021-07-23 12:09:56,921 root         INFO     Will search for bouts through all session z_r12r13_21, 2021-06-10
# 2021-07-23 12:09:56,923 root         INFO     Found 26 files
# [Parallel(n_jobs=28)]: Using backend LokyBackend with 28 concurrent workers.
# [Parallel(n_jobs=28)]: Done   1 tasks      | elapsed:   29.1s
# [Parallel(n_jobs=28)]: Done   2 out of  26 | elapsed:   51.1s remaining: 10.2min
# [Parallel(n_jobs=28)]: Done   3 out of  26 | elapsed:  1.6min remaining: 11.9min
# [Parallel(n_jobs=28)]: Done   4 out of  26 | elapsed:  1.6min remaining:  8.6min
# [Parallel(n_jobs=28)]: Done   5 out of  26 | elapsed:  1.6min remaining:  6.7min
# [Parallel(n_jobs=28)]: Done   6 out of  26 | elapsed:  1.6min remaining:  5.4min
# [Parallel(n_jobs=28)]: Done   7 out of  26 | elapsed:  1.8min remaining:  4.8min
# [Parallel(n_jobs=28)]: Done   8 out of  26 | elapsed:  1.8min remaining:  4.0min
# [Parallel(n_jobs=28)]: Done   9 out of  26 | elapsed:  1.8min remaining:  3.4min
# [Parallel(n_jobs=28)]: Done  10 out of  26 | elapsed:  1.8min remaining:  2.8min
# [Parallel(n_jobs=28)]: Done  11 out of  26 | elapsed:  1.8min remaining:  2.5min
# [Parallel(n_jobs=28)]: Done  12 out of  26 | elapsed:  1.8min remaining:  2.1min
# [Parallel(n_jobs=28)]: Done  13 out of  26 | elapsed:  1.9min remaining:  1.9min
# [Parallel(n_jobs=28)]: Done  14 out of  26 | elapsed:  1.9min remaining:  1.6min
# [Parallel(n_jobs=28)]: Done  15 out of  26 | elapsed:  1.9min remaining:  1.4min
# [Parallel(n_jobs=28)]: Done  16 out of  26 | elapsed:  1.9min remaining:  1.2min
# [Parallel(n_jobs=28)]: Done  17 out of  26 | elapsed:  1.9min remaining:  1.0min
# [Parallel(n_jobs=28)]: Done  18 out of  26 | elapsed:  1.9min remaining:   51.4s
# [Parallel(n_jobs=28)]: Done  19 out of  26 | elapsed:  2.0min remaining:   43.4s
# [Parallel(n_jobs=28)]: Done  20 out of  26 | elapsed:  2.0min remaining:   35.6s
# [Parallel(n_jobs=28)]: Done  21 out of  26 | elapsed:  2.0min remaining:   28.3s
# [Parallel(n_jobs=28)]: Done  22 out of  26 | elapsed:  2.0min remaining:   21.8s
# [Parallel(n_jobs=28)]: Done  23 out of  26 | elapsed:  2.0min remaining:   15.6s
# [Parallel(n_jobs=28)]: Done  24 out of  26 | elapsed:  2.0min remaining:   10.0s
# [Parallel(n_jobs=28)]: Done  26 out of  26 | elapsed:  2.0min remaining:    0.0s
# [Parallel(n_jobs=28)]: Done  26 out of  26 | elapsed:  2.0min finished

# %%
import sys
sys.stdout.flush()

# %%
sess_bout_pd.shape
# Out:
# (1338, 16)

# %% [markdown]
# ### save the pandas for the day as a pickle

# %%
import pickle
import sys

# %%
def save_auto_bouts(sess_bout_pd, sess_par, hparams):
    exp_struct = et.get_exp_struct(sess_par['bird'], sess_par['sess'], ephys_software='alsa')
    sess_bouts_dir = os.path.join(exp_struct['folders']['derived'], 'bouts_ceciestunepipe')

    sess_bouts_path = os.path.join(sess_bouts_dir, hparams['bout_auto_file'])
    hparams_pickle_path = os.path.join(sess_bouts_dir, 'bout_search_params.pickle')

    os.makedirs(sess_bouts_dir, exist_ok=True)
    logger.info('saving bouts pandas to ' + sess_bouts_path)
    sess_bout_pd.to_pickle(sess_bouts_path)

    logger.info('saving bout detect parameters dict to ' + hparams_pickle_path)
    with open(hparams_pickle_path, 'wb') as fh:
        pickle.dump(hparams, fh)
        
save_auto_bouts(sess_bout_pd, sess_par, hparams)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-44-87105fc937fc> in <module>
#      14         pickle.dump(hparams, fh)
#      15
# ---> 16 save_auto_bouts(sess_bout_pd, sess_par, hparams)
#
# <ipython-input-44-87105fc937fc> in save_auto_bouts(sess_bout_pd, sess_par, hparams)
#       6     hparams_pickle_path = os.path.join(sess_bouts_dir, 'bout_search_params.pickle')
#       7
# ----> 8     os.makedirs(sess_bouts_dir, exist_ok=True)
#       9     logger.info('saving bouts pandas to ' + sess_bouts_path)
#      10     sess_bout_pd.to_pickle(sess_bouts_path)
#
# ~/anaconda3/lib/python3.8/os.py in makedirs(name, mode, exist_ok)
#     211     if head and tail and not path.exists(head):
#     212         try:
# --> 213             makedirs(head, exist_ok=exist_ok)
#     214         except FileExistsError:
#     215             # Defeats race condition when another thread created the path
#
# ~/anaconda3/lib/python3.8/os.py in makedirs(name, mode, exist_ok)
#     221             return
#     222     try:
# --> 223         mkdir(name, mode)
#     224     except OSError:
#     225         # Cannot rely on checking for EEXIST, since the operating system
#
# PermissionError: [Errno 13] Permission denied: '/mnt/sphere/speech_bci/derived_data/z_r12r13_21/2021-06-10/alsa'

# %%
sess_bout_pd.head(1)
# Out:
#    start_ms   end_ms  start_sample  end_sample  \
# 0   1290805  1299255      61958640    62364240
#
#                                               p_step     rms_p      peak_p  \
# 0  [0.6991527317204725, 12.869607543970698, 16.55...  1.462951  122.930425
#
#    bout_check                                               file  len_ms  \
# 0        True  /mnt/sphere/speech_bci/raw_data/s_b1253_21/202...    8450
#
#                                               syl_in  n_syl  \
# 0  [[1290805, 1290845], [1291020, 1291065], [1291...     16
#
#                                              peaks_p  n_peaks  l_p_ratio  \
# 0  [4, 19, 30, 47, 60, 72, 88, 109, 122, 136, 149...       82  103.04878
#
#                                             waveform
# 0  [-12, -14, -16, -11, -12, -15, -11, -12, -14, ...

# %% [markdown]
# ### save the bouts of a pandas as wavs

# %%
bird_bouts_folder = os.path.abspath('/mnt/sphere/speech_bci/processed_data/s_b1253_21/bouts_wav')
bird_bouts_folder
# Out:
# '/mnt/sphere/speech_bci/processed_data/s_b1253_21/bouts_wav'

# %%
os.makedirs(bird_bouts_folder, exist_ok=True)

# %%
a_bout = sess_bout_pd.iloc[0]

# %%
a_bout['file']
# Out:
# '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-21/alsa/10-00-01-01.wav'

# %%
def bout_to_wav(a_bout: pd.Series, sess_par, hparams, dest_dir):
    file_name = '{}_{}_{}.wav'.format(sess_par['sess'],
                                      os.path.split(a_bout['file'])[-1].split('.wav')[0],
                                      a_bout['start_ms'])
    file_path = os.path.join(dest_dir, file_name)
    x = a_bout['waveform']
    
    wavfile.write(file_path, hparams['sample_rate'], x)
    return file_path                                                      
    
def bouts_to_wavs(sess_bout_pd, sess_par, hparams, dest_dir):
    # make the dest_dir if does not exist
    logger.info('Saving all session bouts to folder ' + dest_dir)
    os.makedirs(dest_dir, exist_ok=True)
    # write all the motifs to wavs
    sess_bout_pd.apply(lambda x: bout_to_wav(x, sess_par, hparams, dest_dir), axis=1)
    # write the hparams as pickle
    hparams_pickle_path = os.path.join(dest_dir, 'bout_search_params_{}.pickle'.format(sess_par['sess']))
    
    logger.info('saving bout detect parameters dict to ' + hparams_pickle_path)
    with open(hparams_pickle_path, 'wb') as fh:
        pickle.dump(hparams, fh)
    
# one example
sess_bouts_folder = os.path.join(bird_bouts_folder, sess_par['sess'])
os.makedirs(sess_bouts_folder, exist_ok=True)
#bout_to_wav(a_bout, sess_par, hparams, bout_folder)

# all the bouts in the sess
#bouts_to_wavs(sess_bout_pd, sess_par, hparams, bird_bouts_folder)

# %% [markdown]
# ## Run this for all sessions of the bird with alsa recordings

# %% [markdown]
# #### list all sessions

# %%
reload(et)
# Out:
# <module 'ceciestunepipe.file.bcistructure' from '/mnt/cube/earneodo/repos/ceciestunepipe/ceciestunepipe/file/bcistructure.py'>

# %%
all_sessions = et.list_sessions(sess_par['bird'], section='raw', ephys_software='alsa')
all_sessions.sort()
all_sessions
# Out:
# ['2021-05-12',
#  '2021-05-20',
#  '2021-05-21',
#  '2021-05-22',
#  '2021-05-23',
#  '2021-05-24',
#  '2021-05-25',
#  '2021-05-26',
#  '2021-05-27',
#  '2021-05-28',
#  '2021-05-29',
#  '2021-05-30',
#  '2021-05-31',
#  '2021-06-01',
#  '2021-06-02',
#  '2021-06-03',
#  '2021-06-04',
#  '2021-06-05',
#  '2021-06-06',
#  '2021-06-07',
#  '2021-06-08',
#  '2021-06-09',
#  '2021-06-10',
#  '2021-06-11',
#  '2021-06-12',
#  '2021-06-13',
#  '2021-06-14',
#  '2021-06-15',
#  '2021-06-16',
#  '2021-06-17',
#  '2021-06-18',
#  '2021-06-19',
#  '2021-06-20',
#  '2021-06-21',
#  '2021-06-22',
#  '2021-06-23',
#  '2021-06-24',
#  '2021-06-25',
#  '2021-06-26',
#  '2021-06-27',
#  '2021-06-28',
#  '2021-06-29',
#  '2021-06-30',
#  '2021-07-01',
#  '2021-07-02',
#  '2021-07-03',
#  '2021-07-04',
#  '2021-07-05',
#  '2021-07-06',
#  '2021-07-07',
#  '2021-07-08',
#  '2021-07-09',
#  '2021-07-10',
#  '2021-07-11',
#  '2021-07-12',
#  '2021-07-13',
#  '2021-07-14',
#  '2021-07-15',
#  '2021-07-16',
#  '2021-07-17',
#  '2021-07-18',
#  '2021-07-19',
#  '2021-07-20',
#  '2021-07-21',
#  '2021-07-22',
#  '2021-07-23']

# %%
all_sessions[-1:]
# Out:
# ['2021-07-23']

# %%
for sess in all_sessions[-1:]:
    try:
        sess_par['sess'] = sess
        sess_bout_pd = get_all_day_bouts(sess_par, hparams, n_jobs=28)
        save_auto_bouts(sess_bout_pd, sess_par, hparams)
        sess_bouts_folder = os.path.join(bird_bouts_folder, sess)
        bouts_to_wavs(sess_bout_pd, sess_par, hparams, sess_bouts_folder)
    except:
        logger.info('Something went wrong in session ' + sess)
        logger.info('Error {}'.format(sys.exc_info()[0]))
# Out:
# 2021-07-23 09:50:51,795 root         INFO     Will search for bouts through all session s_b1253_21, 2021-07-23
# 2021-07-23 09:50:58,621 root         INFO     Found 4 files
# [Parallel(n_jobs=28)]: Using backend LokyBackend with 28 concurrent workers.
# [Parallel(n_jobs=28)]: Done   1 tasks      | elapsed:   41.3s
# [Parallel(n_jobs=28)]: Done   2 out of   4 | elapsed:   42.4s remaining:   42.4s
# [Parallel(n_jobs=28)]: Done   4 out of   4 | elapsed:   52.5s remaining:    0.0s
# [Parallel(n_jobs=28)]: Done   4 out of   4 | elapsed:   52.5s finished
# 2021-07-23 09:52:00,125 root         INFO     saving bouts pandas to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-23/alsa/bouts_ceciestunepipe/bout_auto.pickle
# 2021-07-23 09:52:06,054 root         INFO     saving bout detect parameters dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-23/alsa/bouts_ceciestunepipe/bout_search_params.pickle
# 2021-07-23 09:52:11,984 root         INFO     Saving all session bouts to folder /mnt/sphere/speech_bci/processed_data/s_b1253_21/bouts_wav/2021-07-23
# 2021-07-23 09:52:58,100 root         INFO     saving bout detect parameters dict to /mnt/sphere/speech_bci/processed_data/s_b1253_21/bouts_wav/2021-07-23/bout_search_params_2021-07-23.pickle
