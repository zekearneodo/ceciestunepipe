# %% [markdown]
# # Pre-processing pipeline for spikeglx sessions, zebra finch
# - For every run in the session:
#  - Load the recordings
#  - Extract wav chan with micrhopohone and make a wav chan with the nidq syn signal
#  - Get the sync events for the nidq sync channel
#
#  - Do bout detection
#
# In another notebook, bout detection is curated
# - Left to decide where to:
#     - Sort spikes
#     - Sync the spikes/lfp/nidq
#     - make and plot 'bout rasters'

# %%
# %matplotlib inline
import os
import glob
import logging
import pickle
import numpy as np
import pandas as pd
from scipy.io import wavfile
from scipy import signal
import traceback
import warnings

from matplotlib import pyplot as plt
from importlib import reload

logger = logging.getLogger()
handler = logging.StreamHandler()
formatter = logging.Formatter(
        '%(asctime)s %(name)-12s %(levelname)-8s %(message)s')
handler.setFormatter(formatter)
logger.addHandler(handler)
logger.setLevel(logging.INFO)

# %%
from ceciestunepipe.file import bcistructure as et
from ceciestunepipe.util import sglxutil as sglu
from ceciestunepipe.util import rigutil as ru
from ceciestunepipe.util import wavutil as wu
from ceciestunepipe.util import syncutil as su

from ceciestunepipe.util.sound import boutsearch as bs

from ceciestunepipe.util.spikeextractors import preprocess as pre
from ceciestunepipe.util.spikeextractors.extractors.spikeglxrecordingextractor import readSGLX as rsgl
from ceciestunepipe.util.spikeextractors.extractors.spikeglxrecordingextractor import spikeglxrecordingextractor as sglex

# %%
import spikeinterface as si
import spikeinterface.extractors as se
import spikeinterface.toolkit as st
import spikeinterface.sorters as ss
import spikeinterface.comparison as sc
import spikeinterface.widgets as sw
logger.info('all modules loaded')
# Out:
# 2022-02-16 04:47:33,898 root         INFO     all modules loaded

# %% [markdown]
# ## Session parameters and raw files

# %% [markdown]
# #### list all the sessions for this bird

# %%
bird = 's_b1253_21'
all_bird_sess = et.list_sessions(bird)
logger.info('all sessions for bird are {}'.format(all_bird_sess))
# Out:
# 2022-02-16 04:47:35,394 root         INFO     all sessions for bird are ['2021-05-12', '2021-05-20', '2021-05-21', '2021-05-22', '2021-05-23', '2021-05-24', '2021-05-25', '2021-05-26', '2021-05-27', '2021-05-28', '2021-05-29', '2021-05-30', '2021-05-31', '2021-06-01', '2021-06-02', '2021-06-03', '2021-06-04', '2021-06-05', '2021-06-06', '2021-06-07', '2021-06-08', '2021-06-09', '2021-06-10', '2021-06-11', '2021-06-12', '2021-06-13', '2021-06-14', '2021-06-15', '2021-06-16', '2021-06-17', '2021-06-18', '2021-06-19', '2021-06-20', '2021-06-21', '2021-06-22', '2021-06-23', '2021-06-24', '2021-06-25', '2021-06-26', '2021-06-27', '2021-06-28', '2021-06-29', '2021-06-30', '2021-07-01', '2021-07-02', '2021-07-03', '2021-07-04', '2021-07-05', '2021-07-06', '2021-07-07', '2021-07-08', '2021-07-09', '2021-07-10', '2021-07-11', '2021-07-12', '2021-07-13', '2021-07-14', '2021-07-15', '2021-07-16', '2021-07-17', '2021-07-18', '2021-07-19', '2021-07-20', '2021-07-21', '2021-07-22', '2021-07-23', '2021-07-24', '2021-07-25', '2021-07-26', '2021-07-27', '2021-07-28', '2021-07-29', '2021-07-30', '2021-07-31', '2021-08-01', '2021-08-02', '2021-08-03', '2021-08-04', '2021-08-05', '2021-08-06', '2021-08-07', '2021-08-08', '2021-08-09', '2021-08-10', '2021-08-11', '2021-08-12', '2021-08-13', '2021-08-14', '2021-08-15', '2021-08-16', '2021-08-17', '2021-08-18', '2021-08-19', '2021-08-20', '2021-08-21', '2021-08-22', '2021-08-23', '2021-08-24', '2021-08-25', '2021-08-26', '2021-08-27', '2021-08-28']

# %% [markdown]
# ### set up bird and sessions parameters
# this will define:
# - locations of files (for the bird)
# - signals and channels to look for in the metadata of the files and in the rig.json parameter file: Note that this have to exist in all of the sessions that will be processed
# - 'sess' is unimportant here, but it comes handy if there is need to debug usin a single session

# %%
reload(et)
# for one example session

sess_par = {'bird': 's_b1253_21',
           'sess': '2021-06-15',
           'probes': ['probe_0'], #probes of interest
           'mic_list': ['microphone_0'], #list of mics of interest, by signal name in rig.json
           'stim_list': ['wav_stim', 'wav_syn'], # list of adc chans with the stimulus
           'nidq_ttl_list': ['wav_ttl'], # list of TTL signals form the nidq digital inputs to extract (besides the 'sync')
           'sort': 2, #label for this sort instance
           }

exp_struct = et.get_exp_struct(sess_par['bird'], sess_par['sess'], sort=sess_par['sort'])

ksort_folder = exp_struct['folders']['ksort']
raw_folder = exp_struct['folders']['sglx']

# %% [markdown]
# list all the epochs in a session, to check that it is finding what it has to find

# %%
sess_epochs = et.list_sgl_epochs(sess_par)
sess_epochs
# Out:
# 2022-02-16 04:47:39,035 ceciestunepipe.file.bcistructure INFO     {'folders': {'bird': '/mnt/sphere/speech_bci/raw_data/s_b1253_21', 'raw': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-06-15', 'sglx': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-06-15/sglx', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-06-15', 'processed': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-06-15/sglx', 'derived': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx', 'tmp': '/scratch/earneodo/tmp', 'msort': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-06-15', 'ksort': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-06-15/2', 'sort': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/2'}, 'files': {'par': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-06-15/2/params.json', 'set': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-06-15/sglx/settings.isf', 'rig': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-06-15/sglx/rig.json', 'kwd': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-06-15/stream.kwd', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-06-15/sort_2/spikes.kwik', 'kwe': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-06-15/events.kwe', 'dat_mic': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-06-15/sglx/dat_mic.mat', 'dat_ap': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-06-15/sglx/dat_ap.mat', 'allevents': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-06-15/sglx/dat_all.pkl', 'wav_mic': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/wav_mic.wav', 'mda_raw': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-06-15/raw.mda', 'bin_raw': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-06-15/2/raw.bin'}}
# ['0701_g0', '0928_g0', '1227_g0', '1617_g0']

# %% [markdown]
# #### define pre-processing steps for each epoch and for the session

# %%
reload(pre)
one_epoch_dict = pre.preprocess_run(sess_par, exp_struct, sess_epochs[0], do_sync_to_stream='ap_0')
# Out:
# 2022-02-16 04:47:46,221 ceciestunepipe.util.spikeextractors.preprocess INFO     PREPROCESSING sess 2021-06-15 | epoch 0701_g0
# 2022-02-16 04:47:46,222 ceciestunepipe.util.spikeextractors.preprocess INFO     getting extractors
# 2022-02-16 04:47:46,280 ceciestunepipe.util.spikeextractors.preprocess INFO     Got sglx recordings for keys ['nidq', 'lf_0', 'ap_0']
# 2022-02-16 04:47:46,281 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting microphone channel(s) ['microphone_0']
# 2022-02-16 04:47:46,281 ceciestunepipe.util.wavutil INFO     sampling rate 25000
# 2022-02-16 04:47:46,282 ceciestunepipe.util.wavutil INFO     saving (1, 220413236)-shaped array as wav in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/wav_mic.wav
# 2022-02-16 04:47:49,991 ceciestunepipe.util.wavutil INFO     saving (1, 220413236)-shaped array as npy in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/wav_mic.npy
# 2022-02-16 04:47:54,383 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting stimulus channel(s) ['wav_stim', 'wav_syn']
# 2022-02-16 04:47:54,387 ceciestunepipe.util.wavutil INFO     sampling rate 25000
# 2022-02-16 04:47:54,388 ceciestunepipe.util.wavutil INFO     saving (2, 220413236)-shaped array as wav in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/wav_stim.wav
# 2022-02-16 04:47:57,513 ceciestunepipe.util.wavutil INFO     saving (2, 220413236)-shaped array as npy in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/wav_stim.npy
# 2022-02-16 04:48:05,986 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting sync channel(s) from nidaq streams: ['sync']
# 2022-02-16 04:48:05,990 ceciestunepipe.util.spikeextractors.extractors.spikeglxrecordingextractor.spikeglxrecordingextractor INFO     getting ttl traces, chan range(0, 7)
# 2022-02-16 04:48:09,031 ceciestunepipe.util.wavutil INFO     sampling rate 25000
# 2022-02-16 04:48:09,032 ceciestunepipe.util.wavutil INFO     saving (1, 220413236)-shaped array as wav in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/wav_sync.wav
# 2022-02-16 04:48:09,701 ceciestunepipe.util.wavutil INFO     saving (1, 220413236)-shaped array as npy in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/wav_sync.npy
# 2022-02-16 04:48:10,335 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting sync events from the wav sync channel
# 2022-02-16 04:48:11,396 ceciestunepipe.util.spikeextractors.preprocess INFO     saving sync events of the wav channel to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/wav_sync_evt.npy
# 2022-02-16 04:48:11,441 ceciestunepipe.util.spikeextractors.preprocess INFO     saving t0 for wav channel to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/wav_t0.npy
# 2022-02-16 04:48:14,634 ceciestunepipe.util.spikeextractors.preprocess INFO     Will get 1 ttl signals
# 2022-02-16 04:48:14,635 ceciestunepipe.util.spikeextractors.preprocess INFO     looking for signal wav_ttl in the nidaq channels
# 2022-02-16 04:48:14,636 ceciestunepipe.util.spikeextractors.preprocess INFO     found in chan 2
# 2022-02-16 04:48:14,637 ceciestunepipe.util.spikeextractors.extractors.spikeglxrecordingextractor.spikeglxrecordingextractor INFO     getting ttl events, chan 2
# 2022-02-16 04:48:16,396 ceciestunepipe.util.spikeextractors.preprocess INFO     saving (0, 2)-shaped array as npy in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/wav_ttl_evt.npy
# 2022-02-16 04:48:16,399 ceciestunepipe.util.spikeextractors.preprocess INFO     saving sync nidaq dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/wav_sync_dict.pkl
# 2022-02-16 04:48:16,473 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting sync signals for imec streams: ['lf_0', 'ap_0']
# 2022-02-16 04:48:16,474 ceciestunepipe.util.spikeextractors.preprocess INFO     getting syn patterns for lf_0
# 2022-02-16 04:48:16,475 ceciestunepipe.util.spikeextractors.preprocess INFO     File /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/lf_0_sync_dict.pkl not found or forced computation, getting the events
# 2022-02-16 04:48:16,476 ceciestunepipe.util.spikeextractors.extractors.spikeglxrecordingextractor.spikeglxrecordingextractor INFO     getting ttl events, chan 0
# 2022-02-16 04:48:16,477 ceciestunepipe.util.spikeextractors.extractors.readSGLX INFO     Extracting digital on imec stream: there is only one channel, if any (SYN) and will be converted from an int16 channel
# 2022-02-16 04:48:16,478 ceciestunepipe.util.spikeextractors.extractors.readSGLX INFO     allocated array for syn channel of size (22041683,)
# 2022-02-16 04:48:53,925 ceciestunepipe.util.spikeextractors.extractors.readSGLX INFO     Threshold for logical hi is 0
# 2022-02-16 04:48:54,215 ceciestunepipe.util.spikeextractors.preprocess INFO     saving events array to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/lf_0_sync_evt.npy
# 2022-02-16 04:48:54,282 ceciestunepipe.util.spikeextractors.preprocess INFO     saving t_0 array to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/lf_0_t0.npy
# 2022-02-16 04:48:54,557 ceciestunepipe.util.spikeextractors.preprocess INFO     saving sync dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/lf_0_sync_dict.pkl
# 2022-02-16 04:48:54,607 ceciestunepipe.util.spikeextractors.preprocess INFO     loading syn_dict from /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/lf_0_sync_dict.pkl
# 2022-02-16 04:48:54,612 ceciestunepipe.util.spikeextractors.preprocess INFO     getting syn patterns for ap_0
# 2022-02-16 04:48:54,613 ceciestunepipe.util.spikeextractors.preprocess INFO     File /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/ap_0_sync_dict.pkl not found or forced computation, getting the events
# 2022-02-16 04:48:54,614 ceciestunepipe.util.spikeextractors.extractors.spikeglxrecordingextractor.spikeglxrecordingextractor INFO     getting ttl events, chan 0
# 2022-02-16 04:48:54,615 ceciestunepipe.util.spikeextractors.extractors.readSGLX INFO     Extracting digital on imec stream: there is only one channel, if any (SYN) and will be converted from an int16 channel
# 2022-02-16 04:48:54,615 ceciestunepipe.util.spikeextractors.extractors.readSGLX INFO     allocated array for syn channel of size (264500195,)
# 2022-02-16 04:50:48,796 ceciestunepipe.util.spikeextractors.extractors.readSGLX INFO     Threshold for logical hi is 0
# 2022-02-16 04:52:24,829 ceciestunepipe.util.spikeextractors.preprocess INFO     saving events array to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/ap_0_sync_evt.npy
# 2022-02-16 04:52:24,889 ceciestunepipe.util.spikeextractors.preprocess INFO     saving t_0 array to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/ap_0_t0.npy
# 2022-02-16 04:52:28,322 ceciestunepipe.util.spikeextractors.preprocess INFO     saving sync dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/ap_0_sync_dict.pkl
# 2022-02-16 04:52:28,326 ceciestunepipe.util.spikeextractors.preprocess INFO     loading syn_dict from /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/ap_0_sync_dict.pkl
# 2022-02-16 04:52:28,330 ceciestunepipe.util.spikeextractors.preprocess INFO     getting syn patterns for nidq
# 2022-02-16 04:52:28,340 ceciestunepipe.util.spikeextractors.preprocess INFO     loading syn_dict from /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/nidq_sync_dict.pkl
# 2022-02-16 04:52:32,805 ceciestunepipe.util.spikeextractors.preprocess INFO     getting syn patterns for wav
# 2022-02-16 04:52:32,808 ceciestunepipe.util.spikeextractors.preprocess INFO     loading syn_dict from /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/wav_sync_dict.pkl
# 2022-02-16 04:52:32,911 ceciestunepipe.util.spikeextractors.preprocess INFO     Will do the sync to stream ap_0
# 2022-02-16 04:52:32,912 ceciestunepipe.util.spikeextractors.preprocess INFO     syncing all times to ap_0
# 2022-02-16 04:52:32,913 ceciestunepipe.util.spikeextractors.preprocess INFO      synch lf_0...
# 2022-02-16 04:52:32,929 ceciestunepipe.util.spikeextractors.preprocess INFO       t_prime file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/lf_0-tp.npy not found or forced computation, getting the events
# 2022-02-16 04:52:47,086 ceciestunepipe.util.spikeextractors.preprocess INFO         saving t_prime array to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/lf_0-tp.npy
# 2022-02-16 04:52:47,385 ceciestunepipe.util.spikeextractors.preprocess INFO         saving synced dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/lf_0_sync_dict.pkl
# 2022-02-16 04:52:48,518 ceciestunepipe.util.spikeextractors.preprocess INFO      synch nidq...
# 2022-02-16 04:52:48,520 ceciestunepipe.util.spikeextractors.preprocess INFO       t_prime file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/nidq-tp.npy not found or forced computation, getting the events
# 2022-02-16 04:56:26,186 ceciestunepipe.util.spikeextractors.preprocess INFO         saving t_prime array to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/nidq-tp.npy
# 2022-02-16 04:56:28,858 ceciestunepipe.util.spikeextractors.preprocess INFO         saving synced dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/nidq_sync_dict.pkl
# 2022-02-16 04:56:46,208 ceciestunepipe.util.spikeextractors.preprocess INFO      synch wav...
# 2022-02-16 04:56:46,211 ceciestunepipe.util.spikeextractors.preprocess INFO       t_prime file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/wav-tp.npy not found or forced computation, getting the events
# 2022-02-16 04:57:44,642 ceciestunepipe.util.spikeextractors.preprocess INFO         saving t_prime array to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/wav-tp.npy
# 2022-02-16 04:57:47,218 ceciestunepipe.util.spikeextractors.preprocess INFO         saving synced dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-15/sglx/0701_g0/wav_sync_dict.pkl

# %%
### sequentially process all runs of the sessions
def preprocess_session(sess_par: dict):
    logger.info('pre-process all runs of sess ' + sess_par['sess'])
    # get exp struct
    sess_struct = et.get_exp_struct(sess_par['bird'], sess_par['sess'], sort=sess_par['sort'])
    # list the epochs
    sess_epochs = et.list_sgl_epochs(sess_par)
    logger.info('found epochs: {}'.format(sess_epochs))
    # preprocess all epochs
    epoch_dict_list = []
    for i_ep, epoch in enumerate(sess_epochs):
        try:
            exp_struct = et.sgl_struct(sess_par, epoch)
            one_epoch_dict = pre.preprocess_run(sess_par, exp_struct, epoch)
            epoch_dict_list.append(one_epoch_dict)
        except Exception as exc:
            warnings.warn('Error in epoch {}'.format(epoch), UserWarning)
            logger.info(traceback.format_exc)
            logger.info(exc)
            logger.info('Session {} epoch {} could not be preprocessed'.format(sess_par['sess'], epoch))
        
    return epoch_dict_list

#all_epoch_list = preprocess_session(sess_par)

# %% [markdown]
# ## Process multiple sessions

# %%
sess_list = all_bird_sess
# fist implant, right hemisphere
sess_list = ['2021-06-12', '2021-06-13', '2021-06-14', '2021-06-15', '2021-06-16', '2021-06-17', '2021-07-01', '2021-07-02', '2021-07-03',
            '2021-07-17', '2021-07-18', '2021-07-19', '2021-07-22', '2021-07-23', '2021-07-24', '2021-07-25', '2021-07-26', '2021-07-27', 
            '2021-07-28', '2021-07-29', '2021-07-30', '2021-07-31']
#sess_list = ['2021-06-12', '2021-06-13']

# %%
all_sess_dict = {}

for one_sess in sess_list[:]:
    sess_par['sess'] = one_sess
    preprocess_session(sess_par)
# Out:
# 2022-02-16 05:21:24,170 root         INFO     pre-process all runs of sess 2021-06-12
# 2022-02-16 05:21:24,172 ceciestunepipe.file.bcistructure INFO     {'folders': {'bird': '/mnt/sphere/speech_bci/raw_data/s_b1253_21', 'raw': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-06-12', 'sglx': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-06-12/sglx', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-06-12', 'processed': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-06-12/sglx', 'derived': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx', 'tmp': '/scratch/earneodo/tmp', 'msort': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-06-12', 'ksort': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-06-12/2', 'sort': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/2'}, 'files': {'par': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-06-12/2/params.json', 'set': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-06-12/sglx/settings.isf', 'rig': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-06-12/sglx/rig.json', 'kwd': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-06-12/stream.kwd', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-06-12/sort_2/spikes.kwik', 'kwe': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-06-12/events.kwe', 'dat_mic': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-06-12/sglx/dat_mic.mat', 'dat_ap': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-06-12/sglx/dat_ap.mat', 'allevents': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-06-12/sglx/dat_all.pkl', 'wav_mic': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/wav_mic.wav', 'mda_raw': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-06-12/raw.mda', 'bin_raw': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-06-12/2/raw.bin'}}
# 2022-02-16 05:21:24,353 root         INFO     found epochs: ['1132_g0', '1631_g0', '714_g0']
# 2022-02-16 05:21:24,354 ceciestunepipe.util.spikeextractors.preprocess INFO     PREPROCESSING sess 2021-06-12 | epoch 1132_g0
# 2022-02-16 05:21:24,355 ceciestunepipe.util.spikeextractors.preprocess INFO     getting extractors
# 2022-02-16 05:21:24,514 ceciestunepipe.util.spikeextractors.preprocess INFO     Got sglx recordings for keys ['nidq', 'lf_0', 'ap_0']
# 2022-02-16 05:21:24,515 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting microphone channel(s) ['microphone_0']
# 2022-02-16 05:21:24,515 ceciestunepipe.util.wavutil INFO     sampling rate 20000
# 2022-02-16 05:21:24,515 ceciestunepipe.util.wavutil INFO     saving (1, 110332786)-shaped array as wav in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/1132_g0/wav_mic.wav
# 2022-02-16 05:21:26,811 ceciestunepipe.util.wavutil INFO     saving (1, 110332786)-shaped array as npy in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/1132_g0/wav_mic.npy
# 2022-02-16 05:21:29,432 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting stimulus channel(s) ['wav_stim', 'wav_syn']
# <ipython-input-10-d2f831978e89>:17: UserWarning: Error in epoch 1132_g0
#   warnings.warn('Error in epoch {}'.format(epoch), UserWarning)
# 2022-02-16 05:21:29,434 root         INFO     <function format_exc at 0x7fc1c415d8b0>
# 2022-02-16 05:21:29,435 root         INFO     invalid literal for int() with base 10: ''
# 2022-02-16 05:21:29,436 root         INFO     Session 2021-06-12 epoch 1132_g0 could not be preprocessed
# 2022-02-16 05:21:29,456 ceciestunepipe.util.spikeextractors.preprocess INFO     PREPROCESSING sess 2021-06-12 | epoch 1631_g0
# 2022-02-16 05:21:29,457 ceciestunepipe.util.spikeextractors.preprocess INFO     getting extractors
# 2022-02-16 05:21:29,841 ceciestunepipe.util.spikeextractors.preprocess INFO     Got sglx recordings for keys ['nidq', 'lf_0', 'ap_0']
# 2022-02-16 05:21:29,842 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting microphone channel(s) ['microphone_0']
# 2022-02-16 05:21:29,843 ceciestunepipe.util.wavutil INFO     sampling rate 20000
# 2022-02-16 05:21:29,844 ceciestunepipe.util.wavutil INFO     saving (1, 276178281)-shaped array as wav in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/1631_g0/wav_mic.wav
# 2022-02-16 05:21:44,015 ceciestunepipe.util.wavutil INFO     saving (1, 276178281)-shaped array as npy in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/1631_g0/wav_mic.npy
# 2022-02-16 05:21:49,637 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting stimulus channel(s) ['wav_stim', 'wav_syn']
# <ipython-input-10-d2f831978e89>:17: UserWarning: Error in epoch 1631_g0
#   warnings.warn('Error in epoch {}'.format(epoch), UserWarning)
# 2022-02-16 05:21:49,639 root         INFO     <function format_exc at 0x7fc1c415d8b0>
# 2022-02-16 05:21:49,640 root         INFO     invalid literal for int() with base 10: ''
# 2022-02-16 05:21:49,640 root         INFO     Session 2021-06-12 epoch 1631_g0 could not be preprocessed
# 2022-02-16 05:21:49,693 ceciestunepipe.util.spikeextractors.preprocess INFO     PREPROCESSING sess 2021-06-12 | epoch 714_g0
# 2022-02-16 05:21:49,694 ceciestunepipe.util.spikeextractors.preprocess INFO     getting extractors
# 2022-02-16 05:21:49,830 ceciestunepipe.util.spikeextractors.preprocess INFO     Got sglx recordings for keys ['nidq', 'lf_0', 'ap_0']
# 2022-02-16 05:21:49,830 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting microphone channel(s) ['microphone_0']
# 2022-02-16 05:21:49,831 ceciestunepipe.util.wavutil INFO     sampling rate 20000
# 2022-02-16 05:21:49,832 ceciestunepipe.util.wavutil INFO     saving (1, 309897239)-shaped array as wav in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/714_g0
 2)-shaped array as npy in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/wav_ttl_evt.npy
# 2022-02-16 06:00:28,937 ceciestunepipe.util.spikeextractors.preprocess INFO     saving sync nidaq dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/wav_sync_dict.pkl
# 2022-02-16 06:00:28,995 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting sync signals for imec streams: ['lf_0', 'ap_0']
# 2022-02-16 06:00:28,996 ceciestunepipe.util.spikeextractors.preprocess INFO     getting syn patterns for lf_0
# 2022-02-16 06:00:29,011 ceciestunepipe.util.spikeextractors.preprocess INFO     File /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/lf_0_sync_dict.pkl not found or forced computation, getting the events
# 2022-02-16 06:00:29,012 ceciestunepipe.util.spikeextractors.extractors.spikeglxrecordingextractor.spikeglxrecordingextractor INFO     getting ttl events, chan 0
# 2022-02-16 06:00:29,012 ceciestunepipe.util.spikeextractors.extractors.readSGLX INFO     Extracting digital on imec stream: there is only one channel, if any (SYN) and will be converted from an int16 channel
# 2022-02-16 06:00:29,013 ceciestunepipe.util.spikeextractors.extractors.readSGLX INFO     allocated array for syn channel of size (46786353,)
# 2022-02-16 06:02:59,689 ceciestunepipe.util.spikeextractors.extractors.readSGLX INFO     Threshold for logical hi is 0
# 2022-02-16 06:03:00,405 ceciestunepipe.util.spikeextractors.preprocess INFO     saving events array to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/lf_0_sync_evt.npy
# 2022-02-16 06:03:01,235 ceciestunepipe.util.spikeextractors.preprocess INFO     saving t_0 array to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/lf_0_t0.npy
# 2022-02-16 06:03:02,183 ceciestunepipe.util.spikeextractors.preprocess INFO     saving sync dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/lf_0_sync_dict.pkl
# 2022-02-16 06:03:02,300 ceciestunepipe.util.spikeextractors.preprocess INFO     loading syn_dict from /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/lf_0_sync_dict.pkl
# 2022-02-16 06:03:02,425 ceciestunepipe.util.spikeextractors.preprocess INFO     getting syn patterns for ap_0
# 2022-02-16 06:03:02,468 ceciestunepipe.util.spikeextractors.preprocess INFO     File /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/ap_0_sync_dict.pkl not found or forced computation, getting the events
# 2022-02-16 06:03:02,468 ceciestunepipe.util.spikeextractors.extractors.spikeglxrecordingextractor.spikeglxrecordingextractor INFO     getting ttl events, chan 0
# 2022-02-16 06:03:02,469 ceciestunepipe.util.spikeextractors.extractors.readSGLX INFO     Extracting digital on imec stream: there is only one channel, if any (SYN) and will be converted from an int16 channel
# 2022-02-16 06:03:02,470 ceciestunepipe.util.spikeextractors.extractors.readSGLX INFO     allocated array for syn channel of size (561436227,)
# 2022-02-16 06:27:26,083 ceciestunepipe.util.spikeextractors.extractors.readSGLX INFO     Threshold for logical hi is 0
# 2022-02-16 06:29:07,076 ceciestunepipe.util.spikeextractors.preprocess INFO     saving events array to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/ap_0_sync_evt.npy
# 2022-02-16 06:29:07,372 ceciestunepipe.util.spikeextractors.preprocess INFO     saving t_0 array to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/ap_0_t0.npy
# 2022-02-16 06:29:13,766 ceciestunepipe.util.spikeextractors.preprocess INFO     saving sync dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/ap_0_sync_dict.pkl
# 2022-02-16 06:29:13,790 ceciestunepipe.util.spikeextractors.preprocess INFO     loading syn_dict from /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/ap_0_sync_dict.pkl
# 2022-02-16 06:29:13,794 ceciestunepipe.util.spikeextractors.preprocess INFO     getting syn patterns for nidq
# 2022-02-16 06:29:13,806 ceciestunepipe.util.spikeextractors.preprocess INFO     loading syn_dict from /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/nidq_sync_dict.pkl
# 2022-02-16 06:29:13,942 ceciestunepipe.util.spikeextractors.preprocess INFO     getting syn patterns for wav
# 2022-02-16 06:29:13,976 ceciestunepipe.util.spikeextractors.preprocess INFO     loading syn_dict from /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/wav_sync_dict.pkl
# 2022-02-16 06:29:14,208 ceciestunepipe.util.spikeextractors.preprocess INFO     PREPROCESSING sess 2021-06-13 | epoch 713_g0
# 2022-02-16 06:29:14,209 ceciestunepipe.util.spikeextractors.preprocess INFO     getting extractors
# 2022-02-16 06:29:14,574 ceciestunepipe.util.spikeextractors.preprocess INFO     Got sglx recordings for keys ['nidq', 'lf_0', 'ap_0']
# 2022-02-16 06:29:14,575 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting microphone channel(s) ['microphone_0']
# 2022-02-16 06:29:14,576 ceciestunepipe.util.wavutil INFO     sampling rate 20000
# 2022-02-16 06:29:14,576 ceciestunepipe.util.wavutil INFO     saving (1, 376432983)-shaped array as wav in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/wav_mic.wav
# 2022-02-16 06:29:31,636 ceciestunepipe.util.wavutil INFO     saving (1, 376432983)-shaped array as npy in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/wav_mic.npy
# 2022-02-16 06:29:39,508 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting stimulus channel(s) ['wav_stim', 'wav_syn']
# 2022-02-16 06:29:39,510 ceciestunepipe.util.wavutil INFO     sampling rate 20000
# 2022-02-16 06:29:39,510 ceciestunepipe.util.wavutil INFO     saving (2, 376432983)-shaped array as wav in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/wav_stim.wav
# 2022-02-16 06:30:52,081 ceciestunepipe.util.wavutil INFO     saving (2, 376432983)-shaped array as npy in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/wav_stim.npy
# 2022-02-16 06:31:09,266 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting sync channel(s) from nidaq streams: ['sync']
# 2022-02-16 06:31:09,268 ceciestunepipe.util.spikeextractors.extractors.spikeglxrecordingextractor.spikeglxrecordingextractor INFO     getting ttl traces, chan range(0, 7)
# 2022-02-16 06:33:09,900 ceciestunepipe.util.wavutil INFO     sampling rate 20000
# 2022-02-16 06:33:09,902 ceciestunepipe.util.wavutil INFO     saving (1, 376432983)-shaped array as wav in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/wav_sync.wav
# 2022-02-16 06:33:12,065 ceciestunepipe.util.wavutil INFO     saving (1, 376432983)-shaped array as npy in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/wav_sync.npy
# 2022-02-16 06:33:13,622 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting sync events from the wav sync channel
# 2022-02-16 06:33:15,515 ceciestunepipe.util.spikeextractors.preprocess INFO     saving sync events of the wav channel to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/wav_sync_evt.npy
# 2022-02-16 06:33:15,760 ceciestunepipe.util.spikeextractors.preprocess INFO     saving t0 for wav channel to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/wav_t0.npy
# 2022-02-16 06:33:43,648 ceciestunepipe.util.spikeextractors.preprocess INFO     Will get 1 ttl signals
# 2022-02-16 06:33:43,650 ceciestunepipe.util.spikeextractors.preprocess INFO     looking for signal wav_ttl in the nidaq channels
# 2022-02-16 06:33:43,651 ceciestunepipe.util.spikeextractors.preprocess INFO     found in chan 2
# 2022-02-16 06:33:43,652 ceciestunepipe.util.spikeextractors.extractors.spikeglxrecordingextractor.spikeglxrecordingextractor INFO     getting ttl events, chan 2
# 2022-02-16 06:34:29,145 ceciestunepipe.util.spikeextractors.preprocess INFO     saving (0, 2)-shaped array as npy in /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/wav_ttl_evt.npy
# 2022-02-16 06:34:29,506 ceciestunepipe.util.spikeextractors.preprocess INFO     saving sync nidaq dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/wav_sync_dict.pkl
# 2022-02-16 06:34:29,580 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting sync signals for imec streams: ['lf_0', 'ap_0']
# 2022-02-16 06:34:29,581 ceciestunepipe.util.spikeextractors.preprocess INFO     getting syn patterns for lf_0
# 2022-02-16 06:34:29,593 ceciestunepipe.util.spikeextractors.preprocess INFO     File /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/lf_0_sync_dict.pkl not found or forced computation, getting the events
# 2022-02-16 06:34:29,593 ceciestunepipe.util.spikeextractors.extractors.spikeglxrecordingextractor.spikeglxrecordingextractor INFO     getting ttl events, chan 0
# 2022-02-16 06:34:29,594 ceciestunepipe.util.spikeextractors.extractors.readSGLX INFO     Extracting digital on imec stream: there is only one channel, if any (SYN) and will be converted from an int16 channel
# 2022-02-16 06:34:29,595 ceciestunepipe.util.spikeextractors.extractors.readSGLX INFO     allocated array for syn channel of size (47057393,)
# 2022-02-16 06:37:11,858 ceciestunepipe.util.spikeextractors.extractors.readSGLX INFO     Threshold for logical hi is 0
# 2022-02-16 06:37:42,342 ceciestunepipe.util.spikeextractors.preprocess INFO     saving events array to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/lf_0_sync_evt.npy
# 2022-02-16 06:37:43,199 ceciestunepipe.util.spikeextractors.preprocess INFO     saving t_0 array to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/lf_0_t0.npy
# 2022-02-16 06:37:43,944 ceciestunepipe.util.spikeextractors.preprocess INFO     saving sync dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/lf_0_sync_dict.pkl
# 2022-02-16 06:37:44,015 ceciestunepipe.util.spikeextractors.preprocess INFO     loading syn_dict from /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/lf_0_sync_dict.pkl
# 2022-02-16 06:37:44,261 ceciestunepipe.util.spikeextractors.preprocess INFO     getting syn patterns for ap_0
# 2022-02-16 06:37:44,271 ceciestunepipe.util.spikeextractors.preprocess INFO     File /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/ap_0_sync_dict.pkl not found or forced computation, getting the events
# 2022-02-16 06:37:44,271 ceciestunepipe.util.spikeextractors.extractors.spikeglxrecordingextractor.spikeglxrecordingextractor INFO     getting ttl events, chan 0
# 2022-02-16 06:37:44,272 ceciestunepipe.util.spikeextractors.extractors.readSGLX INFO     Extracting digital on imec stream: there is only one channel, if any (SYN) and will be converted from an int16 channel
# 2022-02-16 06:37:44,273 ceciestunepipe.util.spikeextractors.extractors.readSGLX INFO     allocated array for syn channel of size (564688710,)
# ...
# 2022-02-16 13:31:50,295 root         INFO     found epochs: []
# 2022-02-16 13:31:50,295 root         INFO     pre-process all runs of sess 2021-07-24
# 2022-02-16 13:31:50,295 ceciestunepipe.file.bcistructure INFO     {'folders': {'bird': '/mnt/sphere/speech_bci/raw_data/s_b1253_21', 'raw': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-24', 'sglx': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-24/sglx', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-24', 'processed': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-24/sglx', 'derived': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-24/sglx', 'tmp': '/scratch/earneodo/tmp', 'msort': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-07-24', 'ksort': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-24/2', 'sort': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-24/sglx/2'}, 'files': {'par': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-24/2/params.json', 'set': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-24/sglx/settings.isf', 'rig': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-24/sglx/rig.json', 'kwd': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-24/stream.kwd', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-24/sort_2/spikes.kwik', 'kwe': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-24/events.kwe', 'dat_mic': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-24/sglx/dat_mic.mat', 'dat_ap': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-24/sglx/dat_ap.mat', 'allevents': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-24/sglx/dat_all.pkl', 'wav_mic': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-24/sglx/wav_mic.wav', 'mda_raw': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-07-24/raw.mda', 'bin_raw': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-24/2/raw.bin'}}
# 2022-02-16 13:31:50,300 root         INFO     found epochs: []
# 2022-02-16 13:31:50,300 root         INFO     pre-process all runs of sess 2021-07-25
# 2022-02-16 13:31:50,300 ceciestunepipe.file.bcistructure INFO     {'folders': {'bird': '/mnt/sphere/speech_bci/raw_data/s_b1253_21', 'raw': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-25', 'sglx': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-25/sglx', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-25', 'processed': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-25/sglx', 'derived': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-25/sglx', 'tmp': '/scratch/earneodo/tmp', 'msort': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-07-25', 'ksort': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-25/2', 'sort': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-25/sglx/2'}, 'files': {'par': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-25/2/params.json', 'set': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-25/sglx/settings.isf', 'rig': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-25/sglx/rig.json', 'kwd': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-25/stream.kwd', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-25/sort_2/spikes.kwik', 'kwe': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-25/events.kwe', 'dat_mic': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-25/sglx/dat_mic.mat', 'dat_ap': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-25/sglx/dat_ap.mat', 'allevents': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-25/sglx/dat_all.pkl', 'wav_mic': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-25/sglx/wav_mic.wav', 'mda_raw': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-07-25/raw.mda', 'bin_raw': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-25/2/raw.bin'}}
# 2022-02-16 13:31:50,347 root         INFO     found epochs: []
# 2022-02-16 13:31:50,347 root         INFO     pre-process all runs of sess 2021-07-26
# 2022-02-16 13:31:50,348 ceciestunepipe.file.bcistructure INFO     {'folders': {'bird': '/mnt/sphere/speech_bci/raw_data/s_b1253_21', 'raw': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-26', 'sglx': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-26/sglx', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-26', 'processed': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-26/sglx', 'derived': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-26/sglx', 'tmp': '/scratch/earneodo/tmp', 'msort': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-07-26', 'ksort': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-26/2', 'sort': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-26/sglx/2'}, 'files': {'par': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-26/2/params.json', 'set': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-26/sglx/settings.isf', 'rig': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-26/sglx/rig.json', 'kwd': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-26/stream.kwd', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-26/sort_2/spikes.kwik', 'kwe': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-26/events.kwe', 'dat_mic': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-26/sglx/dat_mic.mat', 'dat_ap': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-26/sglx/dat_ap.mat', 'allevents': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-26/sglx/dat_all.pkl', 'wav_mic': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-26/sglx/wav_mic.wav', 'mda_raw': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-07-26/raw.mda', 'bin_raw': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-26/2/raw.bin'}}
# 2022-02-16 13:31:50,351 root         INFO     found epochs: []
# 2022-02-16 13:31:50,351 root         INFO     pre-process all runs of sess 2021-07-27
# 2022-02-16 13:31:50,352 ceciestunepipe.file.bcistructure INFO     {'folders': {'bird': '/mnt/sphere/speech_bci/raw_data/s_b1253_21', 'raw': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-27', 'sglx': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-27/sglx', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-27', 'processed': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-27/sglx', 'derived': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-27/sglx', 'tmp': '/scratch/earneodo/tmp', 'msort': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-07-27', 'ksort': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-27/2', 'sort': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-27/sglx/2'}, 'files': {'par': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-27/2/params.json', 'set': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-27/sglx/settings.isf', 'rig': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-27/sglx/rig.json', 'kwd': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-27/stream.kwd', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-27/sort_2/spikes.kwik', 'kwe': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-27/events.kwe', 'dat_mic': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-27/sglx/dat_mic.mat', 'dat_ap': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-27/sglx/dat_ap.mat', 'allevents': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-27/sglx/dat_all.pkl', 'wav_mic': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-27/sglx/wav_mic.wav', 'mda_raw': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-07-27/raw.mda', 'bin_raw': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-27/2/raw.bin'}}
# 2022-02-16 13:31:50,353 root         INFO     found epochs: []
# 2022-02-16 13:31:50,354 root         INFO     pre-process all runs of sess 2021-07-28
# 2022-02-16 13:31:50,354 ceciestunepipe.file.bcistructure INFO     {'folders': {'bird': '/mnt/sphere/speech_bci/raw_data/s_b1253_21', 'raw': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-28', 'sglx': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-28/sglx', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-28', 'processed': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-28/sglx', 'derived': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-28/sglx', 'tmp': '/scratch/earneodo/tmp', 'msort': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-07-28', 'ksort': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-28/2', 'sort': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-28/sglx/2'}, 'files': {'par': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-28/2/params.json', 'set': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-28/sglx/settings.isf', 'rig': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-28/sglx/rig.json', 'kwd': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-28/stream.kwd', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-28/sort_2/spikes.kwik', 'kwe': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-28/events.kwe', 'dat_mic': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-28/sglx/dat_mic.mat', 'dat_ap': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-28/sglx/dat_ap.mat', 'allevents': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-28/sglx/dat_all.pkl', 'wav_mic': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-28/sglx/wav_mic.wav', 'mda_raw': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-07-28/raw.mda', 'bin_raw': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-28/2/raw.bin'}}
# 2022-02-16 13:31:50,356 root         INFO     found epochs: []
# 2022-02-16 13:31:50,356 root         INFO     pre-process all runs of sess 2021-07-29
# 2022-02-16 13:31:50,357 ceciestunepipe.file.bcistructure INFO     {'folders': {'bird': '/mnt/sphere/speech_bci/raw_data/s_b1253_21', 'raw': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-29', 'sglx': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-29/sglx', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-29', 'processed': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-29/sglx', 'derived': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-29/sglx', 'tmp': '/scratch/earneodo/tmp', 'msort': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-07-29', 'ksort': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-29/2', 'sort': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-29/sglx/2'}, 'files': {'par': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-29/2/params.json', 'set': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-29/sglx/settings.isf', 'rig': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-29/sglx/rig.json', 'kwd': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-29/stream.kwd', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-29/sort_2/spikes.kwik', 'kwe': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-29/events.kwe', 'dat_mic': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-29/sglx/dat_mic.mat', 'dat_ap': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-29/sglx/dat_ap.mat', 'allevents': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-29/sglx/dat_all.pkl', 'wav_mic': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-29/sglx/wav_mic.wav', 'mda_raw': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-07-29/raw.mda', 'bin_raw': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-29/2/raw.bin'}}
# 2022-02-16 13:31:50,358 root         INFO     found epochs: []
# 2022-02-16 13:31:50,359 root         INFO     pre-process all runs of sess 2021-07-30
# 2022-02-16 13:31:50,359 ceciestunepipe.file.bcistructure INFO     {'folders': {'bird': '/mnt/sphere/speech_bci/raw_data/s_b1253_21', 'raw': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-30', 'sglx': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-30/sglx', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-30', 'processed': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-30/sglx', 'derived': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-30/sglx', 'tmp': '/scratch/earneodo/tmp', 'msort': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-07-30', 'ksort': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-30/2', 'sort': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-30/sglx/2'}, 'files': {'par': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-30/2/params.json', 'set': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-30/sglx/settings.isf', 'rig': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-30/sglx/rig.json', 'kwd': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-30/stream.kwd', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-30/sort_2/spikes.kwik', 'kwe': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-30/events.kwe', 'dat_mic': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-30/sglx/dat_mic.mat', 'dat_ap': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-30/sglx/dat_ap.mat', 'allevents': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-30/sglx/dat_all.pkl', 'wav_mic': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-30/sglx/wav_mic.wav', 'mda_raw': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-07-30/raw.mda', 'bin_raw': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-30/2/raw.bin'}}
# 2022-02-16 13:31:50,360 root         INFO     found epochs: []
# 2022-02-16 13:31:50,361 root         INFO     pre-process all runs of sess 2021-07-31
# 2022-02-16 13:31:50,361 ceciestunepipe.file.bcistructure INFO     {'folders': {'bird': '/mnt/sphere/speech_bci/raw_data/s_b1253_21', 'raw': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-31', 'sglx': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-31/sglx', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-31', 'processed': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-31/sglx', 'derived': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-31/sglx', 'tmp': '/scratch/earneodo/tmp', 'msort': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-07-31', 'ksort': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-31/2', 'sort': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-31/sglx/2'}, 'files': {'par': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-31/2/params.json', 'set': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-31/sglx/settings.isf', 'rig': '/mnt/sphere/speech_bci/raw_data/s_b1253_21/2021-07-31/sglx/rig.json', 'kwd': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-31/stream.kwd', 'kwik': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-31/sort_2/spikes.kwik', 'kwe': '/scratch/earneodo/s_b1253_21/sglx/kwik/2021-07-31/events.kwe', 'dat_mic': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-31/sglx/dat_mic.mat', 'dat_ap': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-31/sglx/dat_ap.mat', 'allevents': '/mnt/sphere/speech_bci/processed_data/s_b1253_21/2021-07-31/sglx/dat_all.pkl', 'wav_mic': '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-07-31/sglx/wav_mic.wav', 'mda_raw': '/scratch/earneodo/s_b1253_21/sglx/msort/2021-07-31/raw.mda', 'bin_raw': '/scratch/earneodo/s_b1253_21/sglx/ksort/2021-07-31/2/raw.bin'}}
# 2022-02-16 13:31:50,364 root         INFO     found epochs: []

# %%
sess_par
# Out:
# {'bird': 's_b1253_21',
#  'sess': '2021-07-18',
#  'probes': ['probe_0'],
#  'mic_list': ['microphone_0'],
#  'sort': 2}

# %%
# Search bouts

# %% [markdown]
# ## search bouts for those sessions

# %%
from ceciestunepipe.util.sound import boutsearch as bs
from ceciestunepipe.util import wavutil as wu

from joblib import Parallel, delayed
import pickle
import sys

# %%
def sess_file_id(f_path):
    n = int(os.path.split(f_path)[1].split('-')[-1].split('.wav')[0])
    return n


def get_all_day_bouts(sess_par: dict, hparams:dict, n_jobs: int=12, ephys_software='sglx', 
                     parallel=True) -> pd.DataFrame:
    
    logger.info('Will search for bouts through all session {}, {}'.format(sess_par['bird'], sess_par['sess']))
    exp_struct = et.get_exp_struct(sess_par['bird'], sess_par['sess'], ephys_software=ephys_software)

    # get all the paths to the wav files of the epochs of the day   
    source_folder = exp_struct['folders']['derived']
    wav_path_list = et.get_sgl_files_epochs(source_folder, file_filter='*wav_mic.wav')
    wav_path_list.sort()
    logger.info('Found {} files'.format(len(wav_path_list)))
    print(wav_path_list)
    
    get_file_bouts = lambda path: bs.get_epoch_bouts(path, hparams)
    # Go parallel through all the paths in the day, get a list of all the pandas dataframes for each file
    if parallel:
        sess_pd_list = Parallel(n_jobs=n_jobs, verbose=100, prefer='threads')(delayed(get_file_bouts)(i) for i in wav_path_list)
    else:
        sess_pd_list = [get_file_bouts(i) for i in wav_path_list]
    
    #concatenate the file and return it, eventually write to a pickle
    sess_bout_pd = pd.concat(sess_pd_list)
    return sess_bout_pd

def save_auto_bouts(sess_bout_pd, sess_par, hparams):
    exp_struct = et.get_exp_struct(sess_par['bird'], sess_par['sess'], ephys_software='bouts_sglx')
    #sess_bouts_dir = os.path.join(exp_struct['folders']['derived'], 'bouts_ceciestunepipe')
    sess_bouts_dir = exp_struct['folders']['derived']

    sess_bouts_path = os.path.join(sess_bouts_dir, hparams['bout_auto_file'])
    hparams_pickle_path = os.path.join(sess_bouts_dir, 'bout_search_params.pickle')

    os.makedirs(sess_bouts_dir, exist_ok=True)
    logger.info('saving bouts pandas to ' + sess_bouts_path)
    sess_bout_pd.to_pickle(sess_bouts_path)

    logger.info('saving bout detect parameters dict to ' + hparams_pickle_path)
    with open(hparams_pickle_path, 'wb') as fh:
        pickle.dump(hparams, fh)

# %%
hparams = {
    # spectrogram
    'num_freq':1024, #1024# how many channels to use in a spectrogram #
    'preemphasis':0.97, 
    'frame_shift_ms':5, # step size for fft
    'frame_length_ms':10, #128 # frame length for fft FRAME SAMPLES < NUM_FREQ!!!
    'min_level_db':-55, # minimum threshold db for computing spe 
    'ref_level_db':110, # reference db for computing spec
    #'sample_rate':None, # sample rate of your data
    
    # spectrograms
    'mel_filter': False, # should a mel filter be used?
    'num_mels':1024, # how many channels to use in the mel-spectrogram
    'fmin': 500, # low frequency cutoff for mel filter
    'fmax': 12000, # high frequency cutoff for mel filter
    
    # spectrogram inversion
    'max_iters':200,
    'griffin_lim_iters':20,
    'power':1.5,

    # Added for the searching
    'read_wav_fun': wu.read_wav_chan, # function for loading the wav_like_stream (has to returns fs, ndarray)
    'file_order_fun': sess_file_id, # function for extracting the file id within the session
    'min_segment': 30, # Minimum length of supra_threshold to consider a 'syllable' (ms)
    'min_silence': 2000, # Minmum distance between groups of syllables to consider separate bouts (ms)
    'min_bout': 5000, # min bout duration (ms)
    'peak_thresh_rms': 0.55, # threshold (rms) for peak acceptance,
    'thresh_rms': 0.25, # threshold for detection of syllables
    'mean_syl_rms_thresh': 0.3, #threshold for acceptance of mean rms across the syllable (relative to rms of the file)
    'max_bout': 120000, #exclude bouts too long
    'l_p_r_thresh': 100, # threshold for n of len_ms/peaks (typycally about 2-3 syllable spans
    
    'waveform_edges': 1000, #get number of ms before and after the edges of the bout for the waveform sample
    
    'bout_auto_file': 'bout_auto.pickle', # extension for saving the auto found files
    'bout_curated_file': 'bout_checked.pickle', #extension for manually curated files (coming soon)
    }

# %%
all_sessions = sess_list[:2]
#all_sessions = ['2021-06-15']

for sess in all_sessions:
    sess_par['sess'] = sess
    sess_bout_pd = get_all_day_bouts(sess_par, hparams, parallel=False)
    save_auto_bouts(sess_bout_pd, sess_par, hparams)
    sess_bouts_folder = os.path.join(exp_struct['folders']['derived'], 'bouts')
    #bouts_to_wavs(sess_bout_pd, sess_par, hparams, sess_bouts_folder)
# Out:
# 2021-12-03 16:54:27,329 root         INFO     Will search for bouts through all session s_b1253_21, 2021-06-12
# 2021-12-03 16:54:27,615 root         INFO     Found 3 files
# 2021-12-03 16:54:27,616 ceciestunepipe.util.sound.boutsearch INFO     Getting bouts for long file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/1132_g0/wav_mic.wav
# ['/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/1132_g0/wav_mic.wav', '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/1631_g0/wav_mic.wav', '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/714_g0/wav_mic.wav']
# tu vieja file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/1132_g0/wav_mic.wav
# 2021-12-03 16:54:27,699 ceciestunepipe.util.sound.boutsearch INFO     splitting file into 2 chunks
#   0%|          | 0/2 [00:00<?, ?it/s]
# 2021-12-03 16:56:09,773 ceciestunepipe.util.sound.boutsearch INFO     saving bout detect parameters dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/1132_g0/bout_search_params.pickle
# 2021-12-03 16:56:09,841 ceciestunepipe.util.sound.boutsearch INFO     saving bouts pandas to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/1132_g0/bout_auto.pickle
# 2021-12-03 16:56:09,903 ceciestunepipe.util.sound.boutsearch INFO     Getting bouts for long file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/1631_g0/wav_mic.wav
# tu vieja file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/1631_g0/wav_mic.wav
# 2021-12-03 16:56:10,022 ceciestunepipe.util.sound.boutsearch INFO     splitting file into 4 chunks
#   0%|          | 0/4 [00:00<?, ?it/s]
# 2021-12-03 17:01:39,870 ceciestunepipe.util.sound.boutsearch INFO     saving bout detect parameters dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/1631_g0/bout_search_params.pickle
# 2021-12-03 17:01:40,038 ceciestunepipe.util.sound.boutsearch INFO     saving bouts pandas to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/1631_g0/bout_auto.pickle
# 2021-12-03 17:01:40,210 ceciestunepipe.util.sound.boutsearch INFO     Getting bouts for long file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/714_g0/wav_mic.wav
# tu vieja file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/714_g0/wav_mic.wav
# 2021-12-03 17:01:40,274 ceciestunepipe.util.sound.boutsearch INFO     splitting file into 4 chunks
#   0%|          | 0/4 [00:00<?, ?it/s]
# 2021-12-03 17:07:15,074 ceciestunepipe.util.sound.boutsearch INFO     saving bout detect parameters dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/714_g0/bout_search_params.pickle
# 2021-12-03 17:07:15,202 ceciestunepipe.util.sound.boutsearch INFO     saving bouts pandas to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/sglx/714_g0/bout_auto.pickle
# 2021-12-03 17:07:15,660 root         INFO     saving bouts pandas to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/bouts_sglx/bout_auto.pickle
# 2021-12-03 17:07:16,285 root         INFO     saving bout detect parameters dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-12/bouts_sglx/bout_search_params.pickle
# 2021-12-03 17:07:16,288 root         INFO     Will search for bouts through all session s_b1253_21, 2021-06-13
# 2021-12-03 17:07:16,760 root         INFO     Found 5 files
# 2021-12-03 17:07:16,761 ceciestunepipe.util.sound.boutsearch INFO     Getting bouts for long file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/0709_g0/wav_mic.wav
# ['/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/0709_g0/wav_mic.wav', '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/1227_g0/wav_mic.wav', '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/1819_g0/wav_mic.wav', '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/wav_mic.wav', '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/wav_mic.wav']
# tu vieja file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/0709_g0/wav_mic.wav
# 2021-12-03 17:07:16,812 ceciestunepipe.util.sound.boutsearch INFO     splitting file into 1 chunks
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2021-12-03 17:07:19,653 ceciestunepipe.util.sound.boutsearch INFO     saving bout detect parameters dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/0709_g0/bout_search_params.pickle
# 2021-12-03 17:07:19,671 ceciestunepipe.util.sound.boutsearch INFO     saving bouts pandas to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/0709_g0/bout_auto.pickle
# 2021-12-03 17:07:19,708 ceciestunepipe.util.sound.boutsearch INFO     Getting bouts for long file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/1227_g0/wav_mic.wav
# tu vieja file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/1227_g0/wav_mic.wav
# 2021-12-03 17:07:19,762 ceciestunepipe.util.sound.boutsearch INFO     splitting file into 3 chunks
#   0%|          | 0/3 [00:00<?, ?it/s]
# 2021-12-03 17:10:29,324 ceciestunepipe.util.sound.boutsearch INFO     saving bout detect parameters dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/1227_g0/bout_search_params.pickle
# 2021-12-03 17:10:29,560 ceciestunepipe.util.sound.boutsearch INFO     saving bouts pandas to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/1227_g0/bout_auto.pickle
# 2021-12-03 17:10:29,853 ceciestunepipe.util.sound.boutsearch INFO     Getting bouts for long file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/1819_g0/wav_mic.wav
# tu vieja file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/1819_g0/wav_mic.wav
# 2021-12-03 17:10:29,924 ceciestunepipe.util.sound.boutsearch INFO     splitting file into 3 chunks
#   0%|          | 0/3 [00:00<?, ?it/s]
# 2021-12-03 17:13:08,877 ceciestunepipe.util.sound.boutsearch INFO     saving bout detect parameters dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/1819_g0/bout_search_params.pickle
# 2021-12-03 17:13:09,010 ceciestunepipe.util.sound.boutsearch INFO     saving bouts pandas to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/1819_g0/bout_auto.pickle
# 2021-12-03 17:13:09,157 ceciestunepipe.util.sound.boutsearch INFO     Getting bouts for long file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/wav_mic.wav
# tu vieja file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/wav_mic.wav
# 2021-12-03 17:13:09,214 ceciestunepipe.util.sound.boutsearch INFO     splitting file into 5 chunks
#   0%|          | 0/5 [00:00<?, ?it/s]
# 2021-12-03 17:18:32,419 ceciestunepipe.util.sound.boutsearch INFO     saving bout detect parameters dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/bout_search_params.pickle
# 2021-12-03 17:18:32,535 ceciestunepipe.util.sound.boutsearch INFO     saving bouts pandas to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/2342_g0/bout_auto.pickle
# 2021-12-03 17:18:34,546 ceciestunepipe.util.sound.boutsearch INFO     Getting bouts for long file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/wav_mic.wav
# tu vieja file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/wav_mic.wav
# 2021-12-03 17:18:34,558 ceciestunepipe.util.sound.boutsearch INFO     splitting file into 5 chunks
#   0%|          | 0/5 [00:00<?, ?it/s]
# 2021-12-03 17:23:52,669 ceciestunepipe.util.sound.boutsearch INFO     saving bout detect parameters dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/bout_search_params.pickle
# 2021-12-03 17:23:52,883 ceciestunepipe.util.sound.boutsearch INFO     saving bouts pandas to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/sglx/713_g0/bout_auto.pickle
# 2021-12-03 17:23:53,465 root         INFO     saving bouts pandas to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/bouts_sglx/bout_auto.pickle
# 2021-12-03 17:23:56,417 root         INFO     saving bout detect parameters dict to /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-13/bouts_sglx/bout_search_params.pickle

# %%
sess_bout_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103 entries, 0 to 37
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   start_ms      103 non-null    int64
#  1   end_ms        103 non-null    int64
#  2   start_sample  103 non-null    int64
#  3   end_sample    103 non-null    int64
#  4   p_step        103 non-null    object
#  5   rms_p         103 non-null    float64
#  6   peak_p        103 non-null    float64
#  7   bout_check    103 non-null    bool
#  8   file          103 non-null    object
#  9   len_ms        103 non-null    int64
#  10  syl_in        103 non-null    object
#  11  n_syl         103 non-null    int64
#  12  peaks_p       103 non-null    object
#  13  n_peaks       103 non-null    int64
#  14  l_p_ratio     103 non-null    float64
#  15  waveform      103 non-null    object
#  16  confusing     103 non-null    bool
# dtypes: bool(2), float64(3), int64(7), object(5)
# memory usage: 13.1+ KB

# %%
np.unique(sess_bout_pd['start_ms']).size
# Out:
# 103

# %% [markdown]
# # debug

# %% [markdown]
# ## debug search_bout

# %%
## look for a single file
sess = sess_list[0]

exp_struct = et.get_exp_struct(sess_par['bird'], sess, ephys_software='sglx')
source_folder = exp_struct['folders']['derived']
wav_path_list = et.get_sgl_files_epochs(source_folder, file_filter='*wav_mic.wav')
wav_path_list.sort()
logger.info('Found {} files'.format(len(wav_path_list)))
print(wav_path_list)
# Out:
# 2021-09-22 15:13:39,371 root         INFO     Found 4 files
# ['/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-14/sglx/0712_g0/wav_mic.wav', '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-14/sglx/1255_g0/wav_mic.wav', '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-14/sglx/1740_g0/wav_mic.wav', '/mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-14/sglx/2118_g0/wav_mic.wav']

# %%
one_file = wav_path_list[0]

# %%
reload(bs)
epoch_bout_pd, epoch_wav = bs.get_bouts_in_long_file(wav_path_list[0], hparams)
# Out:
# 2021-09-22 15:13:45,924 ceciestunepipe.util.sound.boutsearch INFO     Getting bouts for long file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-14/sglx/0712_g0/wav_mic.wav
# tu vieja file /mnt/sphere/speech_bci/derived_data/s_b1253_21/2021-06-14/sglx/0712_g0/wav_mic.wav
# 2021-09-22 15:13:45,962 ceciestunepipe.util.sound.boutsearch INFO     splitting file into 5 chunks
#   0%|          | 0/5 [00:00<?, ?it/s]
